# %% [markdown]
# ### 1. In the below elements which of them are values or an    expression? eg:- values can be integer or string and    expressions will be mathematical operators.
#
#    ### *, 'hello',   -87.8,   -,   /,   +,   6
#
# #### Answer:-
#     From the given above values are : 'hello'(string),
#                                           -87.8(float),
#                                                  6(int)
#
#     From the given above expressions are : "-"(subraction)
#                                               "+"(addition)
#                                                 "/"(division)

# %% [markdown]
# ### 2. What is the difference between string and variable?
#
# #### Answer:-
#
#     Variable: variables are nothing but simply names created by us own.
#               variables may be assigned with (core data types: Numbers,strings,lists,dictionaries,tuples and Boolean)
#               variables are mainly used in mathematical operations, Before performing the mathematical operation
#               we should declare the value to variable (or) assigning value to variable.
#               variable value may change according to the operations
#               variables may be assigned with (core data types: Numbers,strings,lists,dictionaries,tuples and Boolean)
#               variable values varies upon the performing different operations
#               variable should not contain the spaces between the names
#                             ##### Example: a = 10
#                                            b = 20
#                                            c = a+b  # c value is 30
#                                            a = c-a  # updated 'a' value is 20
#
#     String  : String is basically group of characters enclosed with double quotes(""). Example : "Ineuron.ai"
#                 string is used to save  the textual information.
#                 string is immutable it means it cannot be manipulated
#                 stirng can only perform indexing,slicing and concatenation with other string type
#                 so we can declare string is type of value to the variable but it must be enclosed with double quotes
#
# #### Best examples for variable and strings:
#    * ai = "ineuron"
#    * ml = "machine learning"
#    * data science = ai + ml
#               (where LHS side is variable and RHS side is strings)

# %% [markdown]
# ### 3. Describe three different data types.
#
# #### Answer:-
#
#     python is consist of built-in-data types by default they are basically core datatypes each data type have different      properties among them
#     textual data type: ("string")
#                        string data type is used for save the textual information and must inculde between the double                              quotes("") at begining and ending
#
#     sequence data types:  ("Lists",    "tuples",   "range") are the examples of the data types.
#                          This data type is follows the positionally ordered collection format, This data types have almost                          similar sequence operation such as indexing,concatenation and slicing
#                          Sequences maintain a left-to-right order among the items they contain.
#     Numeric data types : ("int","float","complex") are the examples.
#                          This data types are used almost in mathematical operation and complex scientific calculation
#                          Basically int means integer it include the positive and negative.
#                          and Float include the floating point in it with some precison
#                          complex includes the real and immaginary part values in it example: 12+5j
#     Boolean type : This type is used to check the condition with in bulit function
#                    it gives two outputs either "True" or "False"
#                    If the give condition satisfied it gives "True"
#                    If the give condition not satisfied it gives "False"

# %% [markdown]
# ### 4. What is an expression made up of? What do all expressions do?
#
# #### Answer:-
#     Expression is made up of operand and operators that is used to produce the other values.
#     It performs the operation between the operand and operator basically operators are form the special symbol like
#     "+", "-", "*", "==", "=!", "/", "&", "|" and etc...
#     Each symbols act as operator. operator must be declare between two variables or operands.
#
#     Experssion and there functions
#     let's suppose x = 2, y = 3
#
#      +	   x + y	    Addition          output: 5
#      –     x – y	    Subtraction       output: -1
#      *	   x * y	    Multiplication    output: 6
#      /	   x / y     Division          output: 0.666....
#      //    x // y	Quotient          output: 0   #it produes the output to the nearest value
#      %	   x % y	    Remainder         output: 2
#      **    x ** y	Exponentiation    outpur: 8   # it's meaning is "2 raise to power 3"
#
#       The above expression performs the mathamatical operations it is also known as Arthmetic expressions.
#
#       There are some expression checks for the conditions between operands
#       if the condition is satisfied then it shows the output: True
#       if the condition is not satisfied then it shows the output: False
#
#       >   x>y checks for, Is x is greater than y
#       <   x<y checks for, Is x is less than y
#       >=  x>=y checks for , Is x is greater than or equals to y
#       <=  x<=y checks for, Is x is less than or equals to y
#       ==  x==y checks for both variables are equals to each other or not
#       !=  x!=y checks for both variables are not equals to each other or not
#
#       These all are classified as "Relational expressions"
#
#       Expressions are also classified as "Logical expression".
#       These expressions checks for the condition of with Logical AND and OR gates.
#       These are considered as operators and must declare between the two satisfiy data types.
#
#       x AND y  It performs the AND operations between the two variables.
#       x OR y  It performs the OR operratins between the two variables.
#
#       In some case these logical gates are declared with special symbols like &,|,^,~
#        & ===> stands for the logical AND
#        | ===> stands for the logical OR
#        ^ ===> stands for the logical XOR
#        ~ ===> stands for the invert of the variable
#               Example: ~x = -(x+1)
#                        ~2 = -(2+1)
#                           = -3.
#        These How the expessions works

# %% [markdown]
# ### 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# #### Answers:-
#     The assignment statements and expressions have quiet small difference , But output varies the huge difference
#     in some cases it leads to error of the program.
#     From the above example spam = 10 , Where spam is variable and 10 is value here we assigned the variable with value 10
#     In case in input if we type spam = 10, It executes then any case if we call spam it shows the output 10.
#
#     Where in case of the Expression It checks the condition give to us, In expression The variable value cannot be assigned
#     For example, If we type the spam == 10 in this case it check it with wheather spam is equals to  10 or not. In case if
#     it is true it displays the output "True" or else "False" vice-versa.
#
#     The program only differs with the symbols that is "=","=="
#
#     Example for assignment statements: input==> spam = 10
#                                        input==> spam
#                                        output==> 10
#     Example for expressions statements: input ==> vamshi == krishna
#                                         output ==> IT shows you please declare the "vamshi"
#          In case if we consider the above assignment example executed  then if execute input given below.
#                                            input==> spam == 10
#                                            output==> True

# %% [markdown]
# ### 6. After running the following code, what does the variable bacon contain?
# ###     bacon = 22
# ###     bacon + 1
#
# #### Answer:-
#      The variable bacon contain "22"
#      In Case if we execute the bacon+1 it produces the output as 23
#    > If we declare the bacon = bacon + 1
#    Then bacon contains the "23"

# %% [markdown]
# ### 7. What should the values of the following two terms be?
# ###     'spam' + 'spamspam'
# ###     'spam' * 3
#
# #### Answer:-
#
#     For 'spam'+'spamspam' value is 'spamspamspam'.
#     For 'spam'*3 value is spamspamspam'

# %% [markdown]
# ### 8. Why is eggs a valid variable name while 100 is invalid?
#
# #### Answers:-
#          Basically there are some protocals for the variable
#    * variable must not contains any numerical value or any integers.
#    * variable should not contain any space between any character in between them.In case if we want to declare the space it
#      must done with the UnderScore.
#    * mainly intergers are cannot assign to literals but in case of string can be assigned with any literals and numeric
#      values
#    * so in the above case eggs is a valid variable.

# %% [markdown]
# ### 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# #### Answer:-
#      int() is the function that evaluates and converts the specified value into the integer.
#          *int.bit_length() It represents Number of bits necessary to represent self in binary.
#          *int.as_integer_ratio() Return integer ratio.
#          *int.conjugate() Returns self, the complex conjugate of any int.
#
#      float() is the function that converts into the floating point of either intergers or strings
#          float() is mostly used in the arthmetic operations for quotient,division and remainder to make out exact precise
#          with the floating points
#
#          *float.fromhex()  Create a floating-point number from a hexadecimal string.
#          *float.real()     Displays the real part of a complex number
#          *float.hex()      Return a hexadecimal representation of a floating-point number.
#
#      string() is the funtion that takes only input in textual form. String must be include between the double quotes.
#        The some of the basic in built functions of string are:
#        let's suppose the string = ineuron
#        *The string.capitalize() function returns a string where the first character is the upper case.
#        *The string.lower() function returns a string where all the characters in a given string are lower case.
#        *The string.title() function returns a string where the first character in every word of the string is an upper case.

# %% [markdown]
# ### 10. Why does this expression cause an error? How can you fix it?
# ###        'I have eaten ' + 99 + ' burritos.'
#
# #### Answer:-
#      The expression caused an error because string is cannot concate with any numerical datatype it must be string.
#      string is immutable datatype it means we cannot alter the string.
#
#      The above can be fixed in two ways
#        1) 'I have eaten'+'99'+'burritos'     ==> Output: 'I have eaten99burritos'
#        2) 'I have eaten'+str(99)+'burritos'  ==> Output: 'I have eaten99burritos'
